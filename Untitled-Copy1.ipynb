# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
tips
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 tips
#
# NameError: name 'tips' is not defined

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='sex',style='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='sex',style='time',kind='line')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='time')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips)

# %%
sns.catplot(x='total_bill',y='day',kind='violin',data=tips,hue='sex',split='True')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='violin')
sns.swarmplot(x='day',y='total_bill',data=tips,color='k',size=3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
from numpy.random import randn

# %%
import seaborn as sns

# %%
x=randn(1000)

# %%
sns.distplot(x)
# Out:
# C:\Users\shahd\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
tips=sns.load_dataset("tips")

# %%
x=tips['total_bill']
y=tips['tip']

# %%
sns.jointplot(x=x,y=y)

# %%
sns.jointplot(x=x,y=y,kind='hex')

# %%
sns.jointplot(x=x,y=y,kind='kde')

# %%
sns.pairplot(tips)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)
